# %% [markdown]
# # HW3 Classifying Customer Complaints
# ## Xin Qiu   Andrew ID: xq

# %%
import pandas as pd
import matplotlib.pyplot as plt
file = "Consumer_Complaints.csv"
df = pd.read_csv(file)
# Discard the rows where consumer complaint narrative is blank
df = df[df['Consumer complaint narrative'].notnull()]
df.head()
# Out:
#    Date received           Product                            Sub-product  \
# 1     10/01/2016  Credit reporting                                    NaN
# 2     10/17/2016     Consumer Loan                           Vehicle loan
# 7     06/15/2015  Credit reporting                                    NaN
# 12    02/03/2016   Debt collection  Other (i.e. phone, health club, etc.)
# 16    02/17/2016   Debt collection                            Credit card
#
#                                        Issue  \
# 1     Incorrect information on credit report
# 2                 Managing the loan or lease
# 7   Credit reporting company's investigation
# 12           Disclosure verification of debt
# 16       Improper contact or sharing of info
#
#                                 Sub-issue  \
# 1                          Account status
# 2                                     NaN
# 7          Inadequate help over the phone
# 12   Not given enough info to verify debt
# 16  Talked to a third party about my debt
#
#                          Consumer complaint narrative  \
# 1   I have outdated information on my credit repor...
# 2   I purchased a new car on XXXX XXXX. The car de...
# 7   An account on my credit report has a mistaken ...
# 12  This company refuses to provide me verificatio...
# 16  This complaint is in regards to Square Two Fin...
#
#                               Company public response  \
# 1   Company has responded to the consumer and the ...
# 2                                                 NaN
# 7    Company chooses not to provide a public response
# 12                                                NaN
# 16  Company has responded to the consumer and the ...
#
#                                    Company State ZIP code            Tags  \
# 1   TRANSUNION INTERMEDIATE HOLDINGS, INC.    AL    352XX             NaN
# 2           CITIZENS FINANCIAL GROUP, INC.    PA    177XX  Older American
# 7      Experian Information Solutions Inc.    VA    224XX             NaN
# 12                     The CBE Group, Inc.    TX    752XX             NaN
# 16         SQUARETWO FINANCIAL CORPORATION    NE    693XX             NaN
#
#    Consumer consent provided? Submitted via Date sent to company  \
# 1            Consent provided           Web           10/05/2016
# 2            Consent provided           Web           10/20/2016
# 7            Consent provided           Web           06/15/2015
# 12           Consent provided           Web           02/03/2016
# 16           Consent provided           Web           03/04/2016
#
#    Company response to consumer Timely response? Consumer disputed?  \
# 1       Closed with explanation              Yes                 No
# 2       Closed with explanation              Yes                 No
# 7       Closed with explanation              Yes                 No
# 12      Closed with explanation              Yes                Yes
# 16      Closed with explanation              Yes                Yes
#
#     Complaint ID
# 1        2141773
# 2        2163100
# 7        1420702
# 12       1772196
# 16       1790634

# %%
# This yields 273739 rows.
print(len(df))
# Out:
# 273739

# %% [markdown]
# ## Entity Extraction

# %%
df = df.head(10000)

# %%
# entity extraction
import pandas as pd
import nltk,re,pprint
import matplotlib.pyplot as plt

def preprocess_complaint_narratives(df):
    sentences = []
    for doc in df:
        #Sentence tokenize
        sent = nltk.sent_tokenize(doc)
        #word tokenize
        sent = [nltk.word_tokenize(s) for s in sent]
        #Part of speech tagging
        sent = [nltk.pos_tag(s) for s in sent]
        for s in sent:
            sentences.append(s)
    return sentences

compNarr = df['Consumer complaint narrative']
tokens = preprocess_complaint_narratives(compNarr)
tree = [nltk.chunk.ne_chunk(t) for t in tokens]

def extract_entity_names(t):
    entity_names = []
    if hasattr(t, 'label') and t.label():
        if t.label() == 'ORGANIZATION':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))
    return entity_names

entity_names = []
for t in tree:
    entity_names.extend(extract_entity_names(t))
    
# Get unique entity names
counts={}
for i in entity_names:
    if(i in counts):
        counts[i] +=1
    else:
        counts[i] = 1

# %%
# check which banks are mentioned most (within top 100 range)
# Because the organization tag isn't perfect, we have to manually identify the actual banks.
sort_counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)
sort_counts[0:100]
# Out:
# [('XXXX', 43036),
#  ('Bank', 1011),
#  ('CFPB', 521),
#  ('FCRA', 392),
#  ('NOT', 349),
#  ('THE', 333),
#  ('Navient', 285),
#  ('Equifax', 284),
#  ('Nationstar', 254),
#  ('CREDIT', 246),
#  ('XXXX Bank', 223),
#  ('Capital One', 223),
#  ('Credit', 220),
#  ('PNC', 214),
#  ('TransUnion', 207),
#  ('US Bank', 192),
#  ('BOA', 191),
#  ('Citibank', 184),
#  ('ATM', 178),
#  ('FDCPA', 172),
#  ('Fair Credit', 170),
#  ('USAA', 161),
#  ('LLC', 145),
#  ('NO', 143),
#  ('FTC', 142),
#  ('IRS', 139),
#  ('Transunion', 137),
#  ('Consumer', 125),
#  ('SLS', 125),
#  ('PMI', 123),
#  ('HAMP', 114),
#  ('PayPal', 113),
#  ('SPS', 112),
#  ('FHA', 110),
#  ('ACCOUNT', 103),
#  ('XXXX of', 101),
#  ('AND', 96),
#  ('Social', 96),
#  ('ALL', 95),
#  ('BofA', 94),
#  ('CA', 93),
#  ('American Express', 91),
#  ('OCWEN', 86),
#  ('BANK', 85),
#  ('EQUIFAX', 79),
#  ('VA', 76),
#  ('Fair Debt Collection', 75),
#  ('FL', 75),
#  ('AMEX', 75),
#  ('NFCU', 75),
#  ('PennyMac', 73),
#  ('SunTrust', 73),
#  ('THIS', 71),
#  ('TO', 67),
#  ('NEVER', 66),
#  ('Capital', 66),
#  ('HUD', 65),
#  ('CRA', 65),
#  ('XXXX University', 62),
#  ('ID', 61),
#  ('AES', 60),
#  ('XXXXXXXXXXXX', 59),
#  ('HSBC', 58),
#  ('TD Bank', 57),
#  ('US', 56),
#  ('XXXX of XXXX', 56),
#  ('IBR', 55),
#  ('Credit Card', 54),
#  ('USPS', 53),
#  ('NSF', 53),
#  ('Synchrony Bank', 53),
#  ('Department', 53),
#  ('SSN', 52),
#  ('CitiMortgage', 51),
#  ('XXXX XXXX', 50),
#  ('MY', 50),
#  ('PNC Bank', 50),
#  ('HELOC', 48),
#  ('ANY', 48),
#  ('BoA', 48),
#  ('Federal Trade Commission', 47),
#  ('ACH', 47),
#  ('Macy', 47),
#  ('Nationstar Mortgage', 45),
#  ('XXXX Mortgage', 45),
#  ('PA', 45),
#  ('PSLF', 45),
#  ('FedLoan', 44),
#  ('ASAP', 44),
#  ('CITI', 44),
#  ('Associates', 44),
#  ('Bankruptcy', 43),
#  ('FICO', 43),
#  ('LoanCare', 43),
#  ('Fargo', 43),
#  ('HELP', 43),
#  ('Citizens Bank', 42),
#  ('Identity', 42),
#  ('XXXX Account', 42),
#  ('Wells Fargo', 42)]

# %%
# After identify the actual banks, add actual banks to a new list (show only the first 10 banks)
# Note: Still, it isn't perfect because some banks may have more than one names and are counted separately. (like 'PNC' and 'PNC bank')
banksortcounts = list()
banksortcounts.append(sort_counts[13])
banksortcounts.append(sort_counts[16])
banksortcounts.append(sort_counts[17])
banksortcounts.append(sort_counts[41])
banksortcounts.append(sort_counts[51])
banksortcounts.append(sort_counts[62])
banksortcounts.append(sort_counts[63])
banksortcounts.append(sort_counts[70])
banksortcounts.append(sort_counts[96])
banksortcounts.append(sort_counts[99])
banksortcounts
# Out:
# [('PNC', 214),
#  ('BOA', 191),
#  ('Citibank', 184),
#  ('American Express', 91),
#  ('SunTrust', 73),
#  ('HSBC', 58),
#  ('TD Bank', 57),
#  ('Synchrony Bank', 53),
#  ('Citizens Bank', 42),
#  ('Wells Fargo', 42)]

# %%
# Draw a histogram of number of complaints by bank name (show only top 10).
bankcounts = pd.DataFrame(data = banksortcounts, columns = ['Bank', 'Counts'])
bankcounts.set_index('Bank', inplace = True)
bankdict = bankcounts.to_dict()['Counts']
plt.title("Number of complaints")
plt.bar(range(len(bankdict)), bankdict.values(), align='center')
plt.xticks(range(len(bankdict)), bankdict.keys(), rotation = 80)
plt.show()

# %% [markdown]
# ### What can you conclude about which banks are causing the most complaints?
#
# PNC, BOA, Citibank, American Express, SunTrust, HSBC, TD Bank, Synchrony Bank, Citizens Bank and Wells Fargo are causing the most complaints.

# %% [markdown]
# ## Prediction

# %%
# Create a model to predict the product based on the consumer complaint narrative. 
import pandas as pd
import nltk
import random
from nltk.corpus import stopwords
import numpy as np
from sklearn.linear_model import LogisticRegression

stop_words = set(stopwords.words('english'))
feature_words = set()

# Generates feature vectors for each input x, in an array of shape (len(feature_words),1) - here (63,1)
def issue_features(doc):
	global feature_words
	features = {}
	words = []
	feat = np.zeros(len(feature_words))
	for s in doc.lower().split():
		words.append(s)

	for word in set(words):
		if(word in feature_words):
			feat[feature_words.index(word)] = 1
	return feat


# Generates product labels for each output label y, in an array of shape (len(labels),1)
def product_label(p):
	global labels
	pf = np.zeros(len(labels))
	pf[labels.index(p)] = 1
	return pf


x = df['Consumer complaint narrative']
y = df['Product']

#Get all the unique product labels
labels = list(df.Product.unique())

top = {}
print("Getting feature list")
for label in labels:
	temp = df[df['Product']==label]['Consumer complaint narrative']
	wordc = {}
	filtered = []
	for doc in temp:
		for s in doc.lower().split():
			#Use s only if s is not a stop word
			if(s not in stop_words):
				filtered.append(s)
				if(s in wordc):
					wordc[s] +=1
				else:
					wordc[s] = 1
	topwords = sorted(wordc.items(),key = lambda x:x[1],reverse=True)

	#Get only the top 50 words for each label
	top[label] = topwords[0:50]

occ = {}
for key,val in top.items():
	for w in val:
		if(w[0] in occ):
			occ[w[0]] += w[1]
		else:
			occ[w[0]] = w[1]
		feature_words.add(w[0])

#Feature words are the top 50 occurring words in each label category. We consider all the unique words in this set.
feature_words = list(feature_words)

print("Number of features = " + str(len(feature_words)))
print("##########################")
print("Building feature set")

#Feature set for logistic regression
feature_set = [(issue_features(x1),y1) for x1,y1 in zip(x,y)]

#Split data into training and test data. Use 10% of the data as test data
size = int(len(feature_set)*0.1)

print("Feature set Generated")
print("##########################")
train_set,test_set = feature_set[size:],feature_set[:size]
trainx,trainy = zip(*train_set)
testx,testy = zip(*test_set)

# Using multi-class Logistic regression, try using other classifiers
clf = LogisticRegression(multi_class ='multinomial',solver='lbfgs')

print("Starting the training")

clf.fit(trainx,trainy)

print("Training completed")
print("##########################")

# To calculate accuracy
correct = 0

for x1,y1 in zip(testx,testy):
	predy = clf.predict(np.array([x1]))

	#Use below for Logistic Regression, SVM , BernoulliNB
	if(predy == y1):
		correct += 1

#Print accuracy of the model
print(correct)
print("Accuracy = " , correct/len(test_set))
# Out:
# Getting feature list
# Number of features = 186
# ##########################
# Building feature set
# Feature set Generated
# ##########################
# Starting the training
# Training completed
# ##########################
# 17886
# Accuracy =  0.6534176012859387

# %% [markdown]
# ## What modeling techniques could you use?
#
# I would use multi-class logistic regression. Consumer complaint narratives are the input, and the 18 products are different classes.
#
# ## How accurate are your predictions, and how did you evaluate this?
#
# The accuracy is 65%. The model correctly predicts a large portion of data, but is not perfect (although the number of features is large enough). This is because we are predicting products solely based on consumer complaint narratives, which is limited in prediction. To improve accuracy, other columns like company and tags may be included.
